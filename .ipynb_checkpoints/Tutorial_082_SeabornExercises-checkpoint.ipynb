# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# 1) From the "tips" dataset
#     1. add a percentage tip column to the dataset
#     2. visualize the relationship between tip percentage, with day of week and time
#     3. visualize tip ~ day, time, and number of people (which function allows three variables independent variables at once?)

# %%
import seaborn as sns
import matplotlib.pyplot as plt # not strictly necessary for most plotting applications

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_ptg'] = tips['tip']/tips['total_bill']
tips.head()

sns.pointplot(y = 'tip_ptg', x = 'day', hue = 'time', data = tips)
plt.show()

# %%
sns.catplot(x="size", y="tip_ptg", hue="day",
            col="time", aspect=.6,
            kind="swarm", data=tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-ff0c912e41b7> in <module>()
# ----> 1 sns.catplot(x="size", y="tip_ptg", hue="day",
#       2             col="time", aspect=.6,
#       3             kind="swarm", data=tips);
#
# AttributeError: module 'seaborn' has no attribute 'catplot'

# %%
#if catplot is not working, it's hard to get facets for plotting three ind. variables:
#sns.pointplot(y = 'tip_ptg', x = 'day', hue = 'time', units = 'size', data = tips)

g = sns.FacetGrid(tips, col="time", row = 'day',margin_titles=True)
#f = sns.pointplot(y = 'tip_ptg', x = 'size', hue = 'day', data = tips)
#g.map(f)
g.map(sns.pointplot, 'size', 'tip_ptg')
g.map(sns.regplot, 'size', 'tip_ptg',color=".3", fit_reg=False, x_jitter=.1)
#g.map(plt.scatter, tips['tip_ptg'])
# Out:
# C:\Users\Yaqian\Anaconda3\lib\site-packages\seaborn\axisgrid.py:703: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# 2) Find an interesting trend in the "exercise" dataset

# %%
exercise = sns.load_dataset('exercise')
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.pointplot(x = 'time', y = 'pulse', hue = 'kind', data = exercise)
plt.show()
sns.violinplot(x = 'time', y = 'pulse', hue = 'diet', data = exercise, split = 1)
plt.show()
#pulse is positively correlated with the increase in time and no-fat diet has higher pulse than low-fat diet
#walking does not change pulse from walking much
